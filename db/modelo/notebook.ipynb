# %%
%LOAD postgresql host=localhost dbname=farmacia_testing user=vendedor password='vendedor' port=5432

# %%
SELECT reg FROM information_schema."columns" 
  WHERE table_schema not in ('pg_catalog', 'information_schema') AND
  column_default like 'nextval(%'
# Out:
# 7 rows in set (0.01 sec)+------------------+--------------+-----------------------------+--------------------------------+------------------+------------------------------------------------------------------------------------------------+-------------+-----------+--------------------------+------------------------+-------------------+-------------------------+---------------+--------------------+---------------+--------------------+-----------------------+----------------------+--------------------+-------------------+------------------+----------------+----------------+---------------+-------------+------------------+------------+----------+---------------+--------------+------------+---------------------+----------------+---------------------+-------------+---------------------+----------------+--------------------+------------------+------------------+----------------+--------------+-----------------------+--------------+
# ...

# %%
select * from inventario.producto
# Out:
# Error: unknown data type with typelem: 54024 for colNum: 9 with name: tipo_receta while executing "select * from inventario.producto".
